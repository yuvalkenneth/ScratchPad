# %% [markdown]
# # Lab 5: Preference Tuning Preview
#
# Goal: decide when to move from SFT into DPO or ORPO. Do not start PPO/GRPO-style work until SFT evals, failure categories, and retention checks are stable.
