# %% [markdown]
# # Lab 4: QLoRA Tradeoffs
#
# Goal: compare QLoRA against the default LoRA run. QLoRA should make memory pressure visible; keep it only if the memory savings are worth the quality and throughput tradeoff.
