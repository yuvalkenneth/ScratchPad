# %% [markdown]
# # Lab 1: SFT Sanity
#
# Goal: prove the training stack can learn before running a larger LoRA sweep.
#
# Read the generated `sanity-overfit` manifest, trainer log, and report. The expected pattern is a fast train-loss drop. If that does not happen, debug labels, chat template rendering, masking, and optimizer settings before changing LoRA knobs.

# %%
from pathlib import Path
import json

run_dir = Path('../../experiments/ft_learning/runs/sanity-overfit')
manifest = json.loads((run_dir / 'manifest.json').read_text())
manifest['experiment_id'], manifest['status']
