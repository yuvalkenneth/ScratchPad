# %% [markdown]
# # Lab 3: LoRA Dropout And Target Modules
#
# Goal: learn when regularization and wider adapter targeting help. Compare train-validation gap, heldout tool metrics, retention, runtime, and memory.
